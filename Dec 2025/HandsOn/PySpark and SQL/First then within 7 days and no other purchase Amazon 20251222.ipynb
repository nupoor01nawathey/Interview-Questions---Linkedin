# %%
"""
Find the users who made their first purchase, then exactly one purchase within 7 days, but
never made another purchase after that.

+----------+------------+---------+
| order_id | order_date | user_id |
+----------+------------+---------+
|      101 | 2024-01-01 |       1 |
|      102 | 2024-01-05 |       1 |
|      103 | 2024-01-01 |       2 |
|      104 | 2024-01-20 |       2 |
|      105 | 2024-02-01 |       3 |
|      106 | 2024-02-03 |       3 |
|      107 | 2024-02-10 |       3 |
|      108 | 2024-03-01 |       4 |
|      109 | 2024-03-08 |       4 |
|      110 | 2024-04-01 |       5 |
|      111 | 2024-05-10 |       6 |
|      112 | 2024-05-10 |       6 |
+----------+------------+---------+

+---------+-------------+--------------+
| user_id | first_order | second_order |
+---------+-------------+--------------+
|       1 | 2024-01-01  | 2024-01-05   |
|       4 | 2024-03-01  | 2024-03-08   |
|       6 | 2024-05-10  | 2024-05-10   | 
+---------+-------------+--------------+
"""
orders_data = [
    (101,'2024-01-01',1),
    (102,'2024-01-05',1),
    (103,'2024-01-01',2),
    (104,'2024-01-20',2),
    (105,'2024-02-01',3),
    (106,'2024-02-03',3),
    (107,'2024-02-10',3),
    (108,'2024-03-01',4),
    (109,'2024-03-08',4),
    (110,'2024-04-01',5),
    (111,'2024-05-10',6),
    (112,'2024-05-10',6)
]

orders_df = spark.createDataFrame(orders_data, ["order_id", "order_date", "user_id"])

display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>user_id</th></tr></thead><tbody><tr><td>101</td><td>2024-01-01</td><td>1</td></tr><tr><td>102</td><td>2024-01-05</td><td>1</td></tr><tr><td>103</td><td>2024-01-01</td><td>2</td></tr><tr><td>104</td><td>2024-01-20</td><td>2</td></tr><tr><td>105</td><td>2024-02-01</td><td>3</td></tr><tr><td>106</td><td>2024-02-03</td><td>3</td></tr><tr><td>107</td><td>2024-02-10</td><td>3</td></tr><tr><td>108</td><td>2024-03-01</td><td>4</td></tr><tr><td>109</td><td>2024-03-08</td><td>4</td></tr><tr><td>110</td><td>2024-04-01</td><td>5</td></tr><tr><td>111</td><td>2024-05-10</td><td>6</td></tr><tr><td>112</td><td>2024-05-10</td><td>6</td></tr></tbody></table></div>

# %% [markdown]
# ### SPARK SQL

# %%
orders_df.createOrReplaceTempView("orders")

spark.sql("""
        with cte as (
            select 
                user_id, min(order_date) as first_order, max(order_date) as second_order
            from orders
            group by user_id
            having count(*)=2
        )
        select 
            user_id, first_order, second_order 
        from cte
        where datediff(second_order, first_order) <= 7
    """
).show(truncate=False)
# Out:
# +-------+-----------+------------+
# |user_id|first_order|second_order|
# +-------+-----------+------------+
# |1      |2024-01-01 |2024-01-05  |
# |4      |2024-03-01 |2024-03-08  |
# |6      |2024-05-10 |2024-05-10  |
# +-------+-----------+------------+

# %% [markdown]
# ### DF API

# %%
from pyspark.sql.functions import *

orders_df.groupBy(col("user_id")).agg(
    count(col("user_id")).alias("total_users"), 
    min(col("order_date")).alias("first_order"), 
    max(col("order_date")).alias("second_order")
  ).filter(count(col("user_id")) == lit(2)) \
    .withColumn("date_diff", date_diff(col("second_order"), col("first_order"))) \
    .filter(col("date_diff") <= 7) \
    .drop("date_diff", "total_users") \
    .show(truncate=False)
# Out:
# +-------+-----------+------------+
# |user_id|first_order|second_order|
# +-------+-----------+------------+
# |1      |2024-01-01 |2024-01-05  |
# |4      |2024-03-01 |2024-03-08  |
# |6      |2024-05-10 |2024-05-10  |
# +-------+-----------+------------+
